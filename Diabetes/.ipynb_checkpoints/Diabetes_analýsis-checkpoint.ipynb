# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
diabetes = pd.read_csv('diabetes.csv')

# %%
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
len(diabetes)
# Out:
# 768

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.distplot(diabetes['Pregnancies'])

# %%
corr = diabetes.corr()

# %%
sns.heatmap(corr, annot=False)
plt.show()

# %%
sns.scatterplot(data=diabetes, x='Pregnancies', y='Age', hue='Outcome')

# %%
sns.scatterplot(data=diabetes, x='Glucose', y='Insulin', hue='Outcome')

# %%
sns.scatterplot(data=diabetes, x='BloodPressure', y='BMI', hue='Outcome')

# %%
sns.scatterplot(data=diabetes, x='DiabetesPedigreeFunction', y='BMI', hue='Outcome')

# %%
sns.scatterplot(data=diabetes, x='Age', y='Insulin', hue='Outcome')

# %%
sns.scatterplot(data=diabetes, x='SkinThickness', y='Insulin', hue='Outcome')

# %% [markdown]
# # Pruebas con Modelos

# %%
from sklearn.model_selection import train_test_split

# %%
x = diabetes.iloc[:,:-1]
y= diabetes.iloc[:,8:9]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=4)

# %% [markdown]
# ## Regresion Lineal

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predict = model.predict(x_test)

# %%
model.score(x_test, y_test)
# Out:
# 0.3450674862510468

# %%
model.intercept_
# Out:
# array([-0.81954039])

# %%
model.coef_
# Out:
# array([[ 0.02137646,  0.00537182, -0.00277167, -0.00034146, -0.00018643,
#          0.01416468,  0.15137436,  0.00395555]])

# %%
sns.scatterplot(data=diabetes)

# %% [markdown]
# ## Arbol de decisiones

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model = model.fit(x_train, y_train)

# %%
model.score(x_test, y_test)
# Out:
# 0.70995670995671
